# %%
from simlib import Sim_v1 as Sim

sim = Sim.VotingSimulation(num_voters=200, num_candidates=3, spread_radius=15)

sim.vote()
sim.get_result()
sim.plot()
# Out:
# 投票结果：
# C0: 27
# C1: 105
# C2: 68

# %%
sim1 = Sim.VotingSimulation(num_voters=100, num_candidates=5, spread_radius=20)

sim1.vote()
sim1.get_result()
sim1.plot()
# Out:
# 投票结果：
# C0: 11
# C1: 23
# C2: 19
# C3: 9
# C4: 38

# %%
sim2 = Sim.VotingSimulation(num_voters=1000, num_candidates=5, spread_radius=100)

sim2.vote()
sim2.get_result()
sim2.plot()
# Out:
# 投票结果：
# C0: 158
# C1: 297
# C2: 116
# C3: 154
# C4: 275

# %%
sim3 = Sim.VotingSimulation(num_voters=1000, num_candidates=10, spread_radius=200)

sim3.vote()
sim3.get_result()
sim3.plot()
# Out:
# 投票结果：
# C0: 69
# C1: 153
# C2: 59
# C3: 49
# C4: 244
# C5: 171
# C6: 27
# C7: 125
# C8: 59
# C9: 44
