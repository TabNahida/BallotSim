# %%
from simlib.VoteSim import VotingSimulation
from simlib.VoteSim import evolve_add_noise, evolve_towards_voter_center
from simlib.VoteSim import random_walk, move_towards_winner, cluster_attraction

import numpy as np

# %%
sim = VotingSimulation(num_voters=200,
                       num_candidates=3,
                       center=np.array([0, 0]),
                       spread_radius=15)

# %%
sim.vote()
sim.get_result()
sim.plot()
# Out:
# 投票结果：
#   C0: 71
#   C1: 114
#   C2: 15

# %%
sim.execute(random_walk, step_size=5.0)
sim.vote()
sim.get_result()
sim.plot()
# Out:
# 投票结果：
#   C0: 71
#   C1: 99
#   C2: 30

# %%
sim.execute(move_towards_winner, fraction=0.5)
sim.vote()
sim.get_result()
sim.plot()
# Out:
# 投票结果：
#   C0: 35
#   C1: 145
#   C2: 20

# %%
sim.propose(mode='evolve', evolve_func=evolve_towards_voter_center, fraction=0.3)
sim.vote()
sim.get_result()
sim.plot()
# Out:
# 投票结果：
#   C0: 47
#   C1: 117
#   C2: 36

# %%
sim.propose(mode='evolve', evolve_func=evolve_add_noise, noise_std=0.5)
sim.vote()
sim.get_result()
sim.plot()
# Out:
# 投票结果：
#   C0: 53
#   C1: 111
#   C2: 36
