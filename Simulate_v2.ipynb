# %%
from simlib.VoteSim import VotingSimulation
from simlib.VoteSim import evolve_add_noise, evolve_towards_voter_center, evolve_away_from_voter_center, candidate_random_walk
from simlib.VoteSim import random_walk, move_towards_winner, cluster_attraction, probabilistic_move_towards_winner

import numpy as np

# %%
sim = VotingSimulation(num_voters=200,
                       num_candidates=3,
                       center=np.array([0, 0]),
                       spread_radius=15)

# %%
sim.vote()
sim.get_result()
sim.plot()
# Out:
# Voting results:
#   C0: 90
#   C1: 64
#   C2: 46

# %%
for i in range(5):
    for j in range(5):
        sim.execute(probabilistic_move_towards_winner, fraction=0.2)
        sim.propose(candidate_random_walk, step_size=2.0)
    sim.propose(evolve_away_from_voter_center, fraction=0.2)
    for j in range(5):
        sim.execute(probabilistic_move_towards_winner, fraction=0.2)
        sim.propose(candidate_random_walk, step_size=2.0)
    sim.vote()
    sim.get_result()
    sim.plot()
# Out:
# Voting results:
#   C0: 103
#   C1: 65
#   C2: 32
# Voting results:
#   C0: 132
#   C1: 53
#   C2: 15
# Voting results:
#   C0: 110
#   C1: 48
#   C2: 42
# Voting results:
#   C0: 106
#   C1: 32
#   C2: 62
# Voting results:
#   C0: 116
#   C1: 52
#   C2: 32
